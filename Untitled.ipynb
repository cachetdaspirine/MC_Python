# %%
import numpy as np
import BinarySystem as Bin
import McMove as MCmove
import System as Sys
import random as rd
from pympler import asizeof
# %matplotlib notebook

# %%
rd.seed(888)
BinSyst=Bin.BinarySystem(150,150)
for n in range(100):
    BinSyst.AddMonoAggregateParticle()
    BinSyst.CheckExpansion()

# %%
system=Sys.System(BinSyst.array,eps=0.1)
system.PlotPerSite()
print(system.Energy)
# Out:
# <img src="data:image/png;base64,..." width="700">
# 2.856897215238827

# %%
system.Evolv(BinSyst.array)
print(system.Energy)
asizeof.asizeof(system)
# Out:
# 2.856897104502284
# 181272

# %%
for i in range(100):
    for j in range(10):
        Irm,Jrm=BinSyst.RmRandContiguousParticle()
        IAdd,JAdd=BinSyst.AddMonoAggregateParticle()
    #system.Evolv(BinSyst.array)
    #BinSyst.ReverseMove(Irm,Jrm,IAdd,JAdd)
    Xg,Yg=BinSyst.ComputeCenter()
    BinSyst.TranslateInTheMiddle(Xg,Yg)

    system.Evolv(BinSyst.array)
print(system.Energy)
system.PlotPerSite()
print(asizeof.asizeof(system))
# Out:
# 1.9369050526806386
# <img src="data:image/png;base64,..." width="700">
# 181272

# %%
del(system)
system=Sys.System(BinSyst.array,eps=0.1)
print(system.Energy)
system.PlotPerSite()
print(asizeof.asizeof(system))
# Out:
# 1.9368936349973993
# <img src="data:image/png;base64,..." width="700">
# 181272
